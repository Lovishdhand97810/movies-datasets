# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("D:/CODES/upgrad/Movie+Assignment+Data.csv")
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 5038      2013.0                  470.0        7.7           NaN
# 5039         NaN                  593.0        7.5         16.00
# 5040      2013.0                    0.0        6.3           NaN
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
movies.shape
# Out:
# (5043, 28)

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5029 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
percent = (movies.isnull().sum()/len(movies))*100
percent = percent.round(2)
print(percent)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# movie_facebook_likes          0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies.drop(['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords'],axis=1)
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# 3                     Action|Thriller        Tom Hardy
# 4                         Documentary      Doug Walker
# ...                               ...              ...
# 5038                     Comedy|Drama      Eric Mabius
# 5039     Crime|Drama|Mystery|Thriller      Natalie Zea
# 5040            Drama|Horror|Thriller      Eva Boehnke
# 5041             Comedy|Drama|Romance        Alan Ruck
# 5042                      Documentary      John August
#
#                                             movie_title  num_voted_users  \
# 0                                               Avatar            886204
# 1             Pirates of the Caribbean: At World's End            471220
# 2                                              Spectre            275868
# 3                                The Dark Knight Rises           1144337
# 4     Star Wars: Episode VII - The Force Awakens    ...                8
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered               629
# 5039                         The Following                         73839
# 5040                              A Plague So Pleasant                38
# 5041                                  Shanghai Calling              1255
# 5042                                 My Date with Drew              4285
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                   3054.0  English  237000000.0      2009.0         7.9
# 1                   1238.0  English  300000000.0      2007.0         7.1
# 2                    994.0  English  245000000.0      2015.0         6.8
# 3                   2701.0  English  250000000.0      2012.0         8.5
# 4                      NaN      NaN          NaN         NaN         7.1
# ...                    ...      ...          ...         ...         ...
# 5038                   6.0  English          NaN      2013.0         7.7
# 5039                 359.0  English          NaN         NaN         7.5
# 5040                   3.0  English       1400.0      2013.0         6.3
# 5041                   9.0  English          NaN      2012.0         6.3
# 5042                  84.0  English       1100.0      2004.0         6.6
#
#       movie_facebook_likes
# 0                    33000
# 1                        0
# 2                    85000
# 3                   164000
# 4                        0
# ...                    ...
# 5038                    84
# 5039                 32000
# 5040                    16
# 5041                   660
# 5042                   456
#
# [5043 rows x 13 columns]

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
high_null_cols = percent[percent > 5].index
movies_drop = movies.dropna(subset=high_null_cols)

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here
movies = movies[movies.isnull().sum(axis=1) <= 5]

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies['language'].fillna('English',inplace=True)

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
movies_original = pd.read_csv("D:/CODES/upgrad/Movie+Assignment+Data.csv")

# %%
# Write your code for checking number of retained rows here
original_rows = movies_original.shape[0]
cleaned_rows = movies.shape[0]
print(cleaned_rows)

percentage_retained = (cleaned_rows/original_rows)*100
print(round(percentage_retained,2))
# Out:
# 4969
# 98.53

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
movies['budget'] = movies['budget'] / 1_000_000
movies['gross'] = movies['gross'] / 1_000_000

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies['profit'] =  movies['gross']-movies['budget']
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 5                       475.0                   530.0   Samantha Morton
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes       gross                           genres  \
# 0                     1000.0  760.505847  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309.404152         Action|Adventure|Fantasy
# 2                    11000.0  200.074175        Action|Adventure|Thriller
# 3                    27000.0  448.130642                  Action|Thriller
# 5                      640.0   73.058679          Action|Adventure|Sci-Fi
# ...                      ...         ...                              ...
# 5038                   637.0         NaN                     Comedy|Drama
# 5039                   841.0         NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0         NaN            Drama|Horror|Thriller
# 5041                   946.0    0.010443             Comedy|Drama|Romance
# 5042                    86.0    0.085222                      Documentary
#
#       ... language country  content_rating    budget title_year  \
# 0     ...  English     USA           PG-13  237.0000     2009.0
# 1     ...  English     USA           PG-13  300.0000     2007.0
# 2     ...  English      UK           PG-13  245.0000     2015.0
# 3     ...  English     USA           PG-13  250.0000     2012.0
# 5     ...  English     USA           PG-13  263.7000     2012.0
# ...   ...      ...     ...             ...       ...        ...
# 5038  ...  English  Canada             NaN       NaN     2013.0
# 5039  ...  English     USA           TV-14       NaN        NaN
# 5040  ...  English     USA             NaN    0.0014     2013.0
# 5041  ...  English     USA           PG-13       NaN     2012.0
# 5042  ...  English     USA              PG    0.0011     2004.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                      936.0        7.9         1.78                 33000
# 1                     5000.0        7.1         2.35                     0
# 2                      393.0        6.8         2.35                 85000
# 3                    23000.0        8.5         2.35                164000
# 5                      632.0        6.6         2.35                 24000
# ...                      ...        ...          ...                   ...
# 5038                   470.0        7.7          NaN                    84
# 5039                   593.0        7.5        16.00                 32000
# 5040                     0.0        6.3          NaN                    16
# 5041                   719.0        6.3         2.35                   660
# 5042                    23.0        6.6         1.85                   456
#
#           profit
# 0     523.505847
# 1       9.404152
# 2     -44.925825
# 3     198.130642
# 5    -190.641321
# ...          ...
# 5038         NaN
# 5039         NaN
# 5040         NaN
# 5041         NaN
# 5042    0.084122
#
# [4969 rows x 29 columns]

# %%
# Write your code for sorting the dataframe here
movies.sort_values(by='profit',ascending=False)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                   723.0     178.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 26    Color     James Cameron                   315.0     194.0
# 3024  Color      George Lucas                   282.0     125.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# ...     ...               ...                     ...       ...
# 5036  Color   Anthony Vallone                     NaN      84.0
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 29                      365.0                  1000.0        Judy Greer
# 26                        0.0                   794.0      Kate Winslet
# 3024                      0.0                   504.0     Peter Cushing
# 3080                  14000.0                   548.0       Dee Wallace
# ...                       ...                     ...               ...
# 5036                      2.0                     2.0    John Considine
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
#
#       actor_1_facebook_likes       gross                            genres  \
# 0                     1000.0  760.505847   Action|Adventure|Fantasy|Sci-Fi
# 29                    3000.0  652.177271  Action|Adventure|Sci-Fi|Thriller
# 26                   29000.0  658.672302                     Drama|Romance
# 3024                 11000.0  460.935665   Action|Adventure|Fantasy|Sci-Fi
# 3080                   861.0  434.949459                     Family|Sci-Fi
# ...                      ...         ...                               ...
# 5036                    45.0         NaN                       Crime|Drama
# 5038                   637.0         NaN                      Comedy|Drama
# 5039                   841.0         NaN      Crime|Drama|Mystery|Thriller
# 5040                     0.0         NaN             Drama|Horror|Thriller
# 5041                   946.0    0.010443              Comedy|Drama|Romance
#
#       ... language country  content_rating     budget title_year  \
# 0     ...  English     USA           PG-13  237.00000     2009.0
# 29    ...  English     USA           PG-13  150.00000     2015.0
# 26    ...  English     USA           PG-13  200.00000     1997.0
# 3024  ...  English     USA              PG   11.00000     1977.0
# 3080  ...  English     USA              PG   10.50000     1982.0
# ...   ...      ...     ...             ...        ...        ...
# 5036  ...  English     USA           PG-13    0.00325     2005.0
# 5038  ...  English  Canada             NaN        NaN     2013.0
# 5039  ...  English     USA           TV-14        NaN        NaN
# 5040  ...  English     USA             NaN    0.00140     2013.0
# 5041  ...  English     USA           PG-13        NaN     2012.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                      936.0        7.9         1.78                 33000
# 29                    2000.0        7.0         2.00                150000
# 26                   14000.0        7.7         2.35                 26000
# 3024                  1000.0        8.7         2.35                 33000
# 3080                   725.0        7.9         1.85                 34000
# ...                      ...        ...          ...                   ...
# 5036                    44.0        7.8          NaN                     4
# 5038                   470.0        7.7          NaN                    84
# 5039                   593.0        7.5        16.00                 32000
# 5040                     0.0        6.3          NaN                    16
# 5041                   719.0        6.3         2.35                   660
#
#           profit
# 0     523.505847
# 29    502.177271
# 26    458.672302
# 3024  449.935665
# 3080  424.449459
# ...          ...
# 5036         NaN
# 5038         NaN
# 5039         NaN
# 5040         NaN
# 5041         NaN
#
# [4969 rows x 29 columns]

# %%
top10 = movies.sort_values(by='profit',ascending=False).head(10)
top10
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 29    Color    Colin Trevorrow                   644.0     124.0
# 26    Color      James Cameron                   315.0     194.0
# 3024  Color       George Lucas                   282.0     125.0
# 3080  Color   Steven Spielberg                   215.0     120.0
# 794   Color        Joss Whedon                   703.0     173.0
# 17    Color        Joss Whedon                   703.0     173.0
# 509   Color       Roger Allers                   186.0      73.0
# 240   Color       George Lucas                   320.0     136.0
# 66    Color  Christopher Nolan                   645.0     152.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 29                      365.0                  1000.0         Judy Greer
# 26                        0.0                   794.0       Kate Winslet
# 3024                      0.0                   504.0      Peter Cushing
# 3080                  14000.0                   548.0        Dee Wallace
# 794                       0.0                 19000.0  Robert Downey Jr.
# 17                        0.0                 19000.0  Robert Downey Jr.
# 509                      28.0                   847.0        Nathan Lane
# 240                       0.0                  1000.0        Liam Neeson
# 66                    22000.0                 11000.0       Heath Ledger
#
#       actor_1_facebook_likes       gross  \
# 0                     1000.0  760.505847
# 29                    3000.0  652.177271
# 26                   29000.0  658.672302
# 3024                 11000.0  460.935665
# 3080                   861.0  434.949459
# 794                  26000.0  623.279547
# 17                   26000.0  623.279547
# 509                   2000.0  422.783777
# 240                  20000.0  474.544677
# 66                   23000.0  533.316061
#
#                                         genres  ... language country  \
# 0              Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 29            Action|Adventure|Sci-Fi|Thriller  ...  English     USA
# 26                               Drama|Romance  ...  English     USA
# 3024           Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 3080                             Family|Sci-Fi  ...  English     USA
# 794                    Action|Adventure|Sci-Fi  ...  English     USA
# 17                     Action|Adventure|Sci-Fi  ...  English     USA
# 509   Adventure|Animation|Drama|Family|Musical  ...  English     USA
# 240            Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 66                 Action|Crime|Drama|Thriller  ...  English     USA
#
#       content_rating  budget title_year  actor_2_facebook_likes imdb_score  \
# 0              PG-13   237.0     2009.0                   936.0        7.9
# 29             PG-13   150.0     2015.0                  2000.0        7.0
# 26             PG-13   200.0     1997.0                 14000.0        7.7
# 3024              PG    11.0     1977.0                  1000.0        8.7
# 3080              PG    10.5     1982.0                   725.0        7.9
# 794            PG-13   220.0     2012.0                 21000.0        8.1
# 17             PG-13   220.0     2012.0                 21000.0        8.1
# 509                G    45.0     1994.0                   886.0        8.5
# 240               PG   115.0     1999.0                 14000.0        6.5
# 66             PG-13   185.0     2008.0                 13000.0        9.0
#
#      aspect_ratio  movie_facebook_likes      profit
# 0            1.78                 33000  523.505847
# 29           2.00                150000  502.177271
# 26           2.35                 26000  458.672302
# 3024         2.35                 33000  449.935665
# 3080         1.85                 34000  424.449459
# 794          1.85                123000  403.279547
# 17           1.85                123000  403.279547
# 509          1.66                 17000  377.783777
# 240          2.35                 13000  359.544677
# 66           2.35                 37000  348.316061
#
# [10 rows x 29 columns]

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here
movies=movies.drop_duplicates().reset_index(drop=True)

# %%
# Write code for repeating subtask 2 here
top10 = movies.sort_values(by='profit',ascending=False).head(10)
top10
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 28    Color    Colin Trevorrow                   644.0     124.0
# 25    Color      James Cameron                   315.0     194.0
# 2967  Color       George Lucas                   282.0     125.0
# 3023  Color   Steven Spielberg                   215.0     120.0
# 16    Color        Joss Whedon                   703.0     173.0
# 498   Color       Roger Allers                   186.0      73.0
# 234   Color       George Lucas                   320.0     136.0
# 65    Color  Christopher Nolan                   645.0     152.0
# 429   Color          Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 28                      365.0                  1000.0         Judy Greer
# 25                        0.0                   794.0       Kate Winslet
# 2967                      0.0                   504.0      Peter Cushing
# 3023                  14000.0                   548.0        Dee Wallace
# 16                        0.0                 19000.0  Robert Downey Jr.
# 498                      28.0                   847.0        Nathan Lane
# 234                       0.0                  1000.0        Liam Neeson
# 65                    22000.0                 11000.0       Heath Ledger
# 429                     378.0                   575.0    Josh Hutcherson
#
#       actor_1_facebook_likes       gross  \
# 0                     1000.0  760.505847
# 28                    3000.0  652.177271
# 25                   29000.0  658.672302
# 2967                 11000.0  460.935665
# 3023                   861.0  434.949459
# 16                   26000.0  623.279547
# 498                   2000.0  422.783777
# 234                  20000.0  474.544677
# 65                   23000.0  533.316061
# 429                  34000.0  407.999255
#
#                                         genres  ... language country  \
# 0              Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 28            Action|Adventure|Sci-Fi|Thriller  ...  English     USA
# 25                               Drama|Romance  ...  English     USA
# 2967           Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 3023                             Family|Sci-Fi  ...  English     USA
# 16                     Action|Adventure|Sci-Fi  ...  English     USA
# 498   Adventure|Animation|Drama|Family|Musical  ...  English     USA
# 234            Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 65                 Action|Crime|Drama|Thriller  ...  English     USA
# 429            Adventure|Drama|Sci-Fi|Thriller  ...  English     USA
#
#       content_rating  budget title_year  actor_2_facebook_likes imdb_score  \
# 0              PG-13   237.0     2009.0                   936.0        7.9
# 28             PG-13   150.0     2015.0                  2000.0        7.0
# 25             PG-13   200.0     1997.0                 14000.0        7.7
# 2967              PG    11.0     1977.0                  1000.0        8.7
# 3023              PG    10.5     1982.0                   725.0        7.9
# 16             PG-13   220.0     2012.0                 21000.0        8.1
# 498                G    45.0     1994.0                   886.0        8.5
# 234               PG   115.0     1999.0                 14000.0        6.5
# 65             PG-13   185.0     2008.0                 13000.0        9.0
# 429            PG-13    78.0     2012.0                 14000.0        7.3
#
#      aspect_ratio  movie_facebook_likes      profit
# 0            1.78                 33000  523.505847
# 28           2.00                150000  502.177271
# 25           2.35                 26000  458.672302
# 2967         2.35                 33000  449.935665
# 3023         1.85                 34000  424.449459
# 16           1.85                123000  403.279547
# 498          1.66                 17000  377.783777
# 234          2.35                 13000  359.544677
# 65           2.35                 37000  348.316061
# 429          2.35                140000  329.999255
#
# [10 rows x 29 columns]

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
filter_ =  movies[movies['num_voted_users'] > 25000]
IMDb_Top_250 = pd.DataFrame(filter_.sort_values(by = 'imdb_score',ascending=False).head(250))
IMDb_Top_250['Rank'] = range(1,251)
IMDb_Top_250
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 1909             Color        Frank Darabont                   199.0
# 3403             Color  Francis Ford Coppola                   208.0
# 65               Color     Christopher Nolan                   645.0
# 2782             Color  Francis Ford Coppola                   149.0
# 3417             Color                   NaN                    54.0
# ...                ...                   ...                     ...
# 4178   Black and White         Robert Rossen                   100.0
# 4183             Color     Richard Linklater                   211.0
# 4200             Color            Ari Folman                   231.0
# 841    Black and White     Quentin Tarantino                   304.0
# 2561             Color            Tom Hooper                   479.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 1909     142.0                      0.0                   461.0
# 3403     175.0                      0.0                  3000.0
# 65       152.0                  22000.0                 11000.0
# 2782     220.0                      0.0                  3000.0
# 3417      53.0                      NaN                  1000.0
# ...        ...                      ...                     ...
# 4178     134.0                     31.0                   366.0
# 4183      80.0                      0.0                     3.0
# 4200      90.0                     56.0                     0.0
# 841      137.0                  16000.0                   348.0
# 2561     118.0                      0.0                   520.0
#
#         actor_2_name  actor_1_facebook_likes       gross  \
# 1909  Jeffrey DeMunn                 11000.0   28.341469
# 3403   Marlon Brando                 14000.0  134.821952
# 65      Heath Ledger                 23000.0  533.316061
# 2782       Al Pacino                 22000.0   57.300000
# 3417   Adam Goldberg                  4000.0         NaN
# ...              ...                     ...         ...
# 4178  Jackie Gleason                   654.0         NaN
# 4183    Albert Delpy                    50.0    5.792822
# 4200     Ronny Dayag                    56.0    2.283276
# 841    Michael Parks                   890.0   66.207920
# 2561   Jennifer Ehle                 14000.0  138.795342
#
#                                                  genres  ... country  \
# 1909                                        Crime|Drama  ...     USA
# 3403                                        Crime|Drama  ...     USA
# 65                          Action|Crime|Drama|Thriller  ...     USA
# 2782                                        Crime|Drama  ...     USA
# 3417                               Crime|Drama|Thriller  ...     USA
# ...                                                 ...  ...     ...
# 4178                                        Drama|Sport  ...     USA
# 4183                                      Drama|Romance  ...     USA
# 4200  Animation|Biography|Documentary|Drama|History|War  ...  Israel
# 841                         Action|Crime|Drama|Thriller  ...     USA
# 2561                    Biography|Drama|History|Romance  ...      UK
#
#      content_rating  budget  title_year actor_2_facebook_likes  imdb_score  \
# 1909              R    25.0      1994.0                  745.0         9.3
# 3403              R     6.0      1972.0                10000.0         9.2
# 65            PG-13   185.0      2008.0                13000.0         9.0
# 2782              R    13.0      1974.0                14000.0         9.0
# 3417          TV-MA     NaN         NaN                 1000.0         9.0
# ...             ...     ...         ...                    ...         ...
# 4178        Unrated     2.0      1961.0                  491.0         8.0
# 4183              R     2.7      2004.0                    8.0         8.0
# 4200              R     1.5      2008.0                    0.0         8.0
# 841               R    30.0      2004.0                  387.0         8.0
# 2561              R    15.0      2010.0                 1000.0         8.0
#
#      aspect_ratio movie_facebook_likes      profit Rank
# 1909         1.85               108000    3.341469    1
# 3403         1.85                43000  128.821952    2
# 65           2.35                37000  348.316061    3
# 2782         1.85                14000   44.300000    4
# 3417         1.78                61000         NaN    5
# ...           ...                  ...         ...  ...
# 4178         2.35                    0         NaN  246
# 4183         1.85                13000    3.092822  247
# 4200         1.85                    0    0.783276  248
# 841          2.35                    0   36.207920  249
# 2561         1.85                64000  123.795342  250
#
# [250 rows x 30 columns]

# %%
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English']
Top_Foreign_Lang_Film
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
# Out:
#                  color                     director_name  \
# 4404             Color                      Sergio Leone
# 3953             Color                Fernando Meirelles
# 4645   Black and White                    Akira Kurosawa
# 2334             Color                    Hayao Miyazaki
# 3798             Color                        Raja Menon
# 3957                    26.0         Alexandra Rapaport
# 2774                   471.0                 Bruno Ganz
# 2685                    18.0            Gustav Fröhlich
# 3485                    58.0  Mélissa Désormeaux-Poulin
# 4080                   327.0                Sanjay Dutt
# 3925                    50.0           Soledad Villamil
# 2018                   422.0              Blythe Danner
# 2508                   250.0              Maribel Verdú
# 3361                     4.0              Takeshi Kusao
# 3488                    15.0           Fernanda Machado
# 2775                    93.0                Lola Dueñas
# 4368                   141.0              Paprika Steen
# 1041                    12.0        Anatoliy Solonitsyn
# 4184                    35.0              Jorge Salinas
# 2858                   489.0                    Bin Won
# 3393                   106.0              Gena Rowlands
# 3285                    81.0             Jimmy Shergill
# 2748                   177.0            Mathieu Amalric
# 4064                    11.0       Matheus Nachtergaele
# 4200                     0.0                Ronny Dayag
#
#       actor_1_facebook_likes      gross  \
# 4404                 16000.0   6.100000
# 3953                  1000.0   7.563397
# 4645                   304.0   0.269061
# 2334                    17.0  10.049886
# 3798                    85.0        NaN
# 4176                   380.0  11.284657
# 4812                    36.0   0.925402
# 4558                   786.0   7.098492
# 2286                   893.0   2.298191
# 1307                   218.0   6.498000
# 2914                   362.0  11.433134
# 3617                   397.0   2.197331
# 4028                   717.0   2.181290
# 1277                   326.0  33.201661
# 3957                    74.0   0.610968
# 2774                   918.0   5.501940
# 2685                   136.0   0.026435
# 3485                   131.0   6.857096
# 4080                   464.0        NaN
# 3925                   827.0  20.167424
# 2018                 23000.0   4.710455
# 2508                   634.0  37.623143
# 3361                     6.0   0.439162
# 3488                   585.0   0.008060
# 2775                   273.0   2.086345
# 4368                   280.0   1.647780
# 1041                    29.0        NaN
# 4184                    85.0   5.383834
# 2858                   717.0   1.110186
# 3393                   963.0   4.443403
# 3285                  8000.0   4.018695
# 2748                   413.0   5.990075
# 4064                   119.0   5.595428
# 4200                    56.0   2.283276
#
#                                                  genres  ...       country  \
# 4404                                            Western  ...         Italy
# 3953                                        Crime|Drama  ...        Brazil
# 4645                             Action|Adventure|Drama  ...         Japan
# 2334                 Adventure|Animation|Family|Fantasy  ...         Japan
# 3798                  Action|Drama|History|Thriller|War  ...         India
# 4176                                     Drama|Thriller  ...       Germany
# 4812                                       Drama|Family  ...          Iran
# 4558                                      Drama|Mystery  ...          Iran
# 2286                        Adventure|Animation|Fantasy  ...         Japan
# 1307                 Action|Adventure|Drama|Fantasy|War  ...         India
# 2914                       Adventure|Drama|Thriller|War  ...  West Germany
# 3617                       Comedy|Drama|History|Romance  ...         India
# 4028                             Drama|Mystery|Thriller  ...   South Korea
# 1277                                     Comedy|Romance  ...        France
# 3957                                              Drama  ...       Denmark
# 2774                        Biography|Drama|History|War  ...       Germany
# 2685                                       Drama|Sci-Fi  ...       Germany
# 3485                                  Drama|Mystery|War  ...        Canada
# 4080                               Comedy|Drama|Romance  ...         India
# 3925                             Drama|Mystery|Thriller  ...     Argentina
# 2018                 Adventure|Animation|Family|Fantasy  ...         Japan
# 2508                                  Drama|Fantasy|War  ...         Spain
# 3361                            Action|Animation|Sci-Fi  ...         Japan
# 3488                        Action|Crime|Drama|Thriller  ...        Brazil
# 3925         8.2         2.35                33000    18.167424  130
# 2018         8.2         1.85                13000   -19.289545  138
# 2508         8.2         1.85                27000    24.123143  141
# 3361         8.1         1.85                    0 -1099.560838  146
# 3488         8.1         1.85                11000    -3.991940  148
# 2775         8.1         2.35                    0    -7.913655  152
# 4368         8.1         1.33                 5000     0.347780  158
# 1041         8.1         2.35                    0          NaN  159
# 4184         8.1         1.85                11000     3.383834  174
# 2858         8.1         2.35                    0   -11.689814  198
# 3393         8.0         1.85                14000    -2.856597  199
# 3285         8.0         2.35                27000    -7.981305  209
# 2748         8.0         1.85                13000          NaN  211
# 4064         8.0         2.35                    0     2.695428  223
# 4200         8.0         1.85                    0     0.783276  248
#
# [34 rows x 30 columns]

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# Write your code for extracting the top 10 directors here
top10director = movies.groupby('director_name')['imdb_score'].mean().sort_values(ascending=False).head(10)
print(top10director)
# Out:
# director_name
# Cary Bell            8.700
# Sadyk Sher-Niyaz     8.700
# Charles Chaplin      8.600
# Raja Menon           8.500
# Ron Fricke           8.500
# Damien Chazelle      8.500
# Majid Majidi         8.500
# Sergio Leone         8.475
# Tony Kaye            8.450
# Christopher Nolan    8.425
# Name: imdb_score, dtype: float64

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
movies[['genre_1', 'genre_2']] = movies['genres'].str.split('|', n=1, expand=True)
movies['genre_2'].fillna(movies['genre_1'], inplace=True)
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 4919  Color        Scott Smith                     1.0      87.0
# 4920  Color                NaN                    43.0      43.0
# 4921  Color   Benjamin Roberds                    13.0      76.0
# 4922  Color        Daniel Hsia                    14.0     100.0
# 4923  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       475.0                   530.0   Samantha Morton
# ...                       ...                     ...               ...
# 4919                      2.0                   318.0     Daphne Zuniga
# 4920                      NaN                   319.0     Valorie Curry
# 4921                      0.0                     0.0     Maxwell Moody
# 4922                      0.0                   489.0     Daniel Henney
# 4923                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes       gross                           genres  \
# 0                     1000.0  760.505847  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309.404152         Action|Adventure|Fantasy
# 2                    11000.0  200.074175        Action|Adventure|Thriller
# 3                    27000.0  448.130642                  Action|Thriller
# 4                      640.0   73.058679          Action|Adventure|Sci-Fi
# ...                      ...         ...                              ...
# 4919                   637.0         NaN                     Comedy|Drama
# 4920                   841.0         NaN     Crime|Drama|Mystery|Thriller
# 4921                     0.0         NaN            Drama|Horror|Thriller
# 4922                   946.0    0.010443             Comedy|Drama|Romance
# 4923                    86.0    0.085222                      Documentary
#
#       ... content_rating    budget  title_year  actor_2_facebook_likes  \
# 0     ...          PG-13  237.0000      2009.0                   936.0
# 1     ...          PG-13  300.0000      2007.0                  5000.0
# 2     ...          PG-13  245.0000      2015.0                   393.0
# 3     ...          PG-13  250.0000      2012.0                 23000.0
# 4     ...          PG-13  263.7000      2012.0                   632.0
# ...   ...            ...       ...         ...                     ...
# 4919  ...            NaN       NaN      2013.0                   470.0
# 4920  ...          TV-14       NaN         NaN                   593.0
# 4921  ...            NaN    0.0014      2013.0                     0.0
# 4922  ...          PG-13       NaN      2012.0                   719.0
# 4923  ...             PG    0.0011      2004.0                    23.0
#
#      imdb_score  aspect_ratio movie_facebook_likes      profit      genre_1  \
# 0           7.9          1.78                33000  523.505847       Action
# 1           7.1          2.35                    0    9.404152       Action
# 2           6.8          2.35                85000  -44.925825       Action
# 3           8.5          2.35               164000  198.130642       Action
# 4           6.6          2.35                24000 -190.641321       Action
# ...         ...           ...                  ...         ...          ...
# 4919        7.7           NaN                   84         NaN       Comedy
# 4920        7.5         16.00                32000         NaN        Crime
# 4921        6.3           NaN                   16         NaN        Drama
# 4922        6.3          2.35                  660         NaN       Comedy
# 4923        6.6          1.85                  456    0.084122  Documentary
#
#                        genre_2
# 0     Adventure|Fantasy|Sci-Fi
# 1            Adventure|Fantasy
# 2           Adventure|Thriller
# 3                     Thriller
# 4             Adventure|Sci-Fi
# ...                        ...
# 4919                     Drama
# 4920    Drama|Mystery|Thriller
# 4921           Horror|Thriller
# 4922             Drama|Romance
# 4923               Documentary
#
# [4924 rows x 31 columns]

# %%
movies_by_segment = movies.groupby(['genre_1','genre_2'])['gross'].mean()
print(movies_by_segment)
# Write your code for grouping the dataframe here
# Out:
# genre_1   genre_2
# Action    Action                                                       59.520907
#           Adventure                                                   130.796805
#           Adventure|Animation|Comedy|Crime|Family|Fantasy              13.596911
#           Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller           NaN
#           Adventure|Animation|Comedy|Drama|Family|Sci-Fi              122.823508
#                                                                          ...
# Sci-Fi    Thriller                                                     29.793790
# Thriller  Thriller                                                      0.540970
#           War                                                                NaN
#           Western                                                            NaN
# Western   Western                                                      11.993215
# Name: gross, Length: 904, dtype: float64

# %%
PopGenre = movies_by_segment.sort_values(ascending=False).head(5)
print(PopGenre)
# Write your code for getting the 5 most popular combo of genres here
# Out:
# genre_1    genre_2
# Family     Sci-Fi                                   434.949459
# Adventure  Animation|Drama|Family|Musical           422.783777
#            Animation|Comedy|Drama|Family|Fantasy    356.454367
# Action     Biography|Drama|History|Thriller|War     350.123553
#            Adventure|Fantasy|Sci-Fi                 296.684758
# Name: gross, dtype: float64

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here

Meryl_Streep =  movies[movies['actor_1_name'] == 'Meryl Streep']
print(Meryl_Streep)
# Include all movies in which Meryl_Streep is the lead
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 400   Color    Nancy Meyers                   187.0     120.0
# 1086  Color   Curtis Hanson                    42.0     111.0
# 1184  Color     Nora Ephron                   252.0     123.0
# 1385  Color   David Frankel                   208.0     109.0
# 1458  Color  Robert Redford                   227.0      92.0
# 1549  Color  Sydney Pollack                    66.0     161.0
# 1592  Color   David Frankel                   234.0     100.0
# 1648  Color   Carl Franklin                    64.0     127.0
# 1725  Color  Stephen Frears                    87.0     110.0
# 1897  Color  Stephen Daldry                   174.0     114.0
# 2728  Color  Phyllida Lloyd                   331.0     105.0
# 3076  Color   Robert Altman                   211.0     105.0
# 3574  Color  Fred Zinnemann                    38.0     117.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 400                     278.0                   963.0     Hunter Parrish
# 1086                    161.0                   132.0    Glenn Morshower
# 1184                      0.0                   923.0  Mary Lynn Rajskub
# 1385                     64.0                   505.0      Anne Hathaway
# 1458                      0.0                 10000.0         Tom Cruise
# 1549                    521.0                   184.0      Michael Gough
# 1592                     64.0                   329.0       Steve Carell
# 1648                     73.0                   433.0       William Hurt
# 1725                    350.0                    83.0       Nina Arianda
# 1897                    335.0                   530.0    Stephen Dillane
# 2728                     58.0                   583.0      Jim Broadbent
# 3076                    500.0                   718.0    Virginia Madsen
# 3574                    160.0                   898.0         Jane Fonda
#
#       actor_1_facebook_likes       gross  \
# 400                  11000.0  112.703470
# 1086                 11000.0   46.815748
# 1184                 11000.0   94.125426
# 1385                 11000.0  124.732962
# 1458                 11000.0   14.998070
# 1549                 11000.0   87.100000
# 1592                 11000.0   63.536011
# 1648                 11000.0   23.209440
# 1725                 11000.0         NaN
# 1897                 11000.0   41.597830
# 2728                 11000.0   29.959436
# 3076                 11000.0   20.338609
# 3574                 11000.0         NaN
#
#                                     genres  ... content_rating budget  \
# 400                   Comedy|Drama|Romance  ...              R  85.00
# 1086       Action|Adventure|Crime|Thriller  ...          PG-13  45.00
# 1184               Biography|Drama|Romance  ...          PG-13  40.00
# 1385                  Comedy|Drama|Romance  ...          PG-13  35.00
# 1458                    Drama|Thriller|War  ...              R  35.00
# 1549               Biography|Drama|Romance  ...             PG  31.00
# 1592                  Comedy|Drama|Romance  ...          PG-13  30.00
# 1648                                 Drama  ...              R  30.00
# 1725  Biography|Comedy|Drama|Music|Romance  ...          PG-13  29.00
# 1897                         Drama|Romance  ...          PG-13  25.00
# 2728               Biography|Drama|History  ...          PG-13  13.00
# 3076                    Comedy|Drama|Music  ...          PG-13  10.00
# 3574                                 Drama  ...             PG   7.84
#
#       title_year  actor_2_facebook_likes imdb_score  aspect_ratio  \
# 400       2009.0                  2000.0        6.6          1.85
# 1086      1994.0                   894.0        6.3          2.35
# 1184      2009.0                   935.0        7.0          1.85
# 1385      2006.0                 11000.0        6.8          2.35
# 1458      2007.0                 10000.0        6.2          2.35
# 1549      1985.0                   920.0        7.2          1.85
# 1592      2012.0                  7000.0        6.3          2.35
# 1648      1998.0                   882.0        7.0          1.85
# 1725      2016.0                   183.0        7.1          2.35
# 1897      2002.0                   577.0        7.6          1.85
# 2728      2011.0                  1000.0        6.4          2.35
# 3076      2006.0                   912.0        6.8          2.35
# 3574      1977.0                   949.0        7.4          1.85
#
#      movie_facebook_likes     profit    genre_1                     genre_2
# 400                     0  27.703470     Comedy               Drama|Romance
# 1086                    0   1.815748     Action    Adventure|Crime|Thriller
# 1184                13000  54.125426  Biography               Drama|Romance
# 1385                    0  89.732962     Comedy               Drama|Romance
# 1458                    0 -20.001930      Drama                Thriller|War
# 1549                    0  56.100000  Biography               Drama|Romance
# 1592                    0  33.536011     Comedy               Drama|Romance
# 1648                  592  -6.790560      Drama                       Drama
# 1725                    0        NaN  Biography  Comedy|Drama|Music|Romance
# 1897                    0  16.597830      Drama                     Romance
# 2728                18000  16.959436  Biography               Drama|History
# 3076                  683  10.338609     Comedy                 Drama|Music
# 3574                  733        NaN      Drama                       Drama
#
# [13 rows x 31 columns]

# %%
Leo_Caprio = movies[movies['actor_1_name'] == 'Leonardo DiCaprio']
print(Leo_Caprio)
# 96    Action|Adventure|Sci-Fi|Thriller  ...          PG-13  160.0      2010.0
# 177   Adventure|Drama|Thriller|Western  ...              R  135.0      2015.0
# 251                    Biography|Drama  ...          PG-13  110.0      2004.0
# 289                      Drama|Western  ...              R  100.0      2012.0
# 299           Adventure|Drama|Thriller  ...              R  100.0      2006.0
# 300       Biography|Comedy|Crime|Drama  ...              R  100.0      2013.0
# 318                        Crime|Drama  ...              R  100.0      2002.0
# 353               Crime|Drama|Thriller  ...              R   90.0      2006.0
# 442                   Mystery|Thriller  ...              R   80.0      2010.0
# 628              Action|Drama|Thriller  ...              R   70.0      2008.0
# 894              Biography|Crime|Drama  ...          PG-13   52.0      2002.0
# 972           Adventure|Drama|Thriller  ...              R   50.0      2000.0
# 1094                     Drama|Romance  ...              R   35.0      2008.0
# 1399                  Action|Adventure  ...          PG-13   35.0      1998.0
# 1428             Biography|Crime|Drama  ...              R   35.0      2011.0
# 1534           Action|Thriller|Western  ...              R   32.0      1995.0
# 2038                             Drama  ...          PG-13   23.0      1996.0
# 2708                     Drama|Romance  ...          PG-13   14.5      1996.0
# 3413                     Drama|Romance  ...          PG-13  105.0      2013.0
#
#       actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes  \
# 25                   14000.0        7.7          2.35                26000
# 49                     509.0        7.3          2.35               115000
# 96                   27000.0        8.8          2.35               175000
# 177                  27000.0        8.1          2.35               190000
# 251                   3000.0        7.5          2.35                    0
# 289                  11000.0        8.5          2.35               199000
# 299                   3000.0        8.0          2.35                14000
# 300                  11000.0        8.2          2.35               138000
# 318                  14000.0        7.5          2.35                    0
# 353                  13000.0        8.5          2.35                29000
# 442                    223.0        8.1          2.35                53000
# 628                    149.0        7.1          2.35                    0
# 894                  15000.0        8.0          1.85                15000
# 972                    414.0        6.6          2.35                    0
# 1094                 14000.0        7.3          2.35                    0
# 1399                   130.0        6.4          1.85                    0
# 1428                  6000.0        6.6          2.35                16000
# 1534                   165.0        6.4          1.85                    0
# 2038                 22000.0        6.7          1.85                 1000
# 2708                  1000.0        6.8          2.35                10000
# 3413                   509.0        7.3          2.35               115000
#
#           profit    genre_1                    genre_2
# 25    458.672302      Drama                    Romance
# 49     39.812796      Drama                    Romance
# 96    132.568851     Action  Adventure|Sci-Fi|Thriller
# 177    48.635922  Adventure     Drama|Thriller|Western
# 251    -7.391173  Biography                      Drama
# 289    62.804648      Drama                    Western
# 299   -42.633738  Adventure             Drama|Thriller
# 300    16.866727  Biography         Comedy|Crime|Drama
# 318   -22.320362      Crime                      Drama
# 353    42.373442      Crime             Drama|Thriller
# 442    47.968405    Mystery                   Thriller
# 628   -30.619558     Action             Drama|Thriller
# 894   112.435221  Biography                Crime|Drama
# 972   -10.221401  Adventure             Drama|Thriller
# 1094  -12.122192      Drama                    Romance
# 1399   21.876365     Action                  Adventure
# 1428    2.304950  Biography                Crime|Drama
# 1534  -13.363463     Action           Thriller|Western
# 2038  -10.217492      Drama                      Drama
# 2708   31.838728      Drama                    Romance
# 3413   39.812796      Drama                    Romance
#
# [21 rows x 31 columns]

# %%
Brad_Pitt = movies[movies['actor_1_name'] == 'Brad Pitt']
print(Brad_Pitt)
# Include all movies in which Brad_Pitt is the lead
# Out:
#                  color          director_name  num_critic_for_reviews  \
# 100              Color          David Fincher                   362.0
# 145              Color      Wolfgang Petersen                   220.0
# 248              Color      Steven Soderbergh                   198.0
# 249              Color             Doug Liman                   233.0
# 374              Color             Tony Scott                   142.0
# 390              Color      Steven Soderbergh                   186.0
# 459              Color             David Ayer                   406.0
# 598              Color    Jean-Jacques Annaud                    76.0
# 669              Color          David Fincher                   315.0
# 777              Color        Patrick Gilmore                    98.0
# 923              Color            Neil Jordan                   120.0
# 1465             Color        Terrence Malick                   584.0
# 1695             Color         Andrew Dominik                   273.0
# 2171             Color  Alejandro G. Iñárritu                   285.0
# 2296             Color    Angelina Jolie Pitt                   131.0
# 2635             Color         Andrew Dominik                   414.0
# 2842             Color             Tony Scott                   122.0
# 4647   Black and White            Tom DiCillo                    10.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 100      166.0                  21000.0                   919.0
# 145      196.0                    249.0                   844.0
# 248      125.0                      0.0                   350.0
# 249      126.0                    218.0                   322.0
# 374      114.0                  12000.0                   307.0
# 390      116.0                      0.0                   471.0
# 459      134.0                    452.0                   697.0
# 598      136.0                    218.0                   400.0
# 669      151.0                  21000.0                   637.0
# 777       85.0                      0.0                    82.0
# 923      123.0                    277.0                  4000.0
# 1465     139.0                      0.0                   687.0
# 1695     160.0                    181.0                   820.0
# 2171     143.0                      0.0                    51.0
# 2296     122.0                  11000.0                   188.0
# 2635      97.0                    181.0                   748.0
# 2842     121.0                  12000.0                   975.0
# 4647      97.0                     32.0                   329.0
#
#              actor_2_name  actor_1_facebook_likes       gross  \
# 100         Jason Flemyng                 11000.0  127.490802
# 145         Orlando Bloom                 11000.0  133.228348
# 248         Julia Roberts                 11000.0  125.531634
# 249   Angelina Jolie Pitt                 11000.0  186.336103
# 374       Stephen Dillane                 11000.0    0.026871
# 390            Bernie Mac                 11000.0  183.405771
# 459          Logan Lerman                 11000.0   85.707116
# 598                  Mako                 11000.0   37.901509
# 669             Meat Loaf                 11000.0   37.023395
# 777      Adriano Giannini                 11000.0   26.288320
# 923            Tom Cruise                 11000.0  105.264608
# 1465         Tye Sheridan                 11000.0   13.303319
# 1695        Jeremy Renner                 11000.0    3.904982
# 2171       Harriet Walter                 11000.0   34.300771
# 2296  Angelina Jolie Pitt                 11000.0    0.531009
# 2635          Sam Shepard                 11000.0   14.938570
# 2842          Gary Oldman                 11000.0   12.281500
# 4647          Tina Louise                 11000.0         NaN
#
#                                                  genres  ... content_rating  \
# 100                               Drama|Fantasy|Romance  ...          PG-13
# 145                                           Adventure  ...              R
# 248                                      Crime|Thriller  ...          PG-13
# 249                Action|Comedy|Crime|Romance|Thriller  ...          PG-13
# 374                               Action|Crime|Thriller  ...              R
# 390                                      Crime|Thriller  ...          PG-13
# 459                                    Action|Drama|War  ...              R
# 598               Adventure|Biography|Drama|History|War  ...          PG-13
# 669                                               Drama  ...              R
# 777   Adventure|Animation|Comedy|Drama|Family|Fantas...  ...             PG
# 923                                Drama|Fantasy|Horror  ...              R
# 1465                                      Drama|Fantasy  ...          PG-13
# 1695              Biography|Crime|Drama|History|Western  ...              R
# 2171                                              Drama  ...              R
# 2296                                      Drama|Romance  ...              R
# 2635                                     Crime|Thriller  ...              R
# 2842                Action|Crime|Drama|Romance|Thriller  ...              R
# 4647                               Comedy|Music|Romance  ...              R
#
#      budget  title_year  actor_2_facebook_likes imdb_score  aspect_ratio  \
# 100   150.0      2008.0                  1000.0        7.8          2.35
# 145   175.0      2004.0                  5000.0        7.2          2.35
# 248   110.0      2004.0                  8000.0        6.4          2.35
# 249   120.0      2005.0                 11000.0        6.5          2.35
# 374    92.0      2001.0                   577.0        7.0          2.35
# 390    85.0      2001.0                  1000.0        7.8          2.35
# 459    68.0      2014.0                  8000.0        7.6          2.35
# 598    70.0      1997.0                   691.0        7.0          2.35
# 669    63.0      1999.0                   783.0        8.8          2.35
# 777    60.0      2003.0                   102.0        6.7          1.66
# 923    60.0      1994.0                 10000.0        7.6          1.85
# 1465   32.0      2011.0                  1000.0        6.7          1.85
# 1695   30.0      2007.0                 10000.0        7.5          2.35
# 2171   25.0      2006.0                   119.0        7.5          1.85
# 2296   10.0      2015.0                 11000.0        5.3          2.35
# 2635   15.0      2012.0                   820.0        6.2          2.35
# 2842   13.0      1993.0                 10000.0        8.0          2.35
# 4647    0.5      1991.0                   422.0        5.8          1.85
#
#      movie_facebook_likes     profit    genre_1  \
# 100                 23000 -22.509198      Drama
# 145                     0 -41.771652  Adventure
# 248                     0  15.531634      Crime
# 249                     0  66.336103     Action
# 374                     0 -91.973129     Action
# 390                     0  98.405771      Crime
# 459                 82000  17.707116     Action
# 598                     0 -32.098491  Adventure
# 669                 48000 -25.976605      Drama
# 777                   880 -33.711680  Adventure
# 923                 11000  45.264608      Drama
# 1465                39000 -18.696681      Drama
# 1695                    0 -26.095018  Biography
# 2171                    0   9.300771      Drama
# 2296                    0  -9.468991      Drama
# 2635                20000  -0.061430      Crime
# 2842                15000  -0.718500     Action
# 4647                  344        NaN     Comedy
#
#                                             genre_2
# 100                                 Fantasy|Romance
# 145                                       Adventure
# 248                                        Thriller
# 249                   Comedy|Crime|Romance|Thriller
# 374                                  Crime|Thriller
# 390                                        Thriller
# 459                                       Drama|War
# 598                     Biography|Drama|History|War
# 669                                           Drama
# 777   Animation|Comedy|Drama|Family|Fantasy|Romance
# 923                                  Fantasy|Horror
# 1465                                        Fantasy
# 1695                    Crime|Drama|History|Western
# 2171                                          Drama
# 2296                                        Romance
# 2635                                       Thriller
# 2842                   Crime|Drama|Romance|Thriller
# 4647                                  Music|Romance
#
# [18 rows x 31 columns]

# %%
# Write your code for combining the three dataframes here
Combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt], ignore_index=True)
Combined
# Out:
#                color          director_name  num_critic_for_reviews  duration  \
# 0              Color           Nancy Meyers                   187.0     120.0
# 1              Color          Curtis Hanson                    42.0     111.0
# 2              Color            Nora Ephron                   252.0     123.0
# 3              Color          David Frankel                   208.0     109.0
# 4              Color         Robert Redford                   227.0      92.0
# 5              Color         Sydney Pollack                    66.0     161.0
# 48                 11000.0    0.531009
# 49                 11000.0   14.938570
# 50                 11000.0   12.281500
# 51                 11000.0         NaN
#
#                                                genres  ... content_rating  \
# 0                                Comedy|Drama|Romance  ...              R
# 1                     Action|Adventure|Crime|Thriller  ...          PG-13
# 2                             Biography|Drama|Romance  ...          PG-13
# 3                                Comedy|Drama|Romance  ...          PG-13
# 4                                  Drama|Thriller|War  ...              R
# 5                             Biography|Drama|Romance  ...             PG
# 6                                Comedy|Drama|Romance  ...          PG-13
# 7                                               Drama  ...              R
# 8                Biography|Comedy|Drama|Music|Romance  ...          PG-13
# 9                                       Drama|Romance  ...          PG-13
# 10                            Biography|Drama|History  ...          PG-13
# 11                                 Comedy|Drama|Music  ...          PG-13
# 12                                              Drama  ...             PG
# 13                                      Drama|Romance  ...          PG-13
# 14                                      Drama|Romance  ...          PG-13
# 15                   Action|Adventure|Sci-Fi|Thriller  ...          PG-13
# 16                   Adventure|Drama|Thriller|Western  ...              R
# 17                                    Biography|Drama  ...          PG-13
# 18                                      Drama|Western  ...              R
# 19                           Adventure|Drama|Thriller  ...              R
# 20                       Biography|Comedy|Crime|Drama  ...              R
# 21                                        Crime|Drama  ...              R
# 22                               Crime|Drama|Thriller  ...              R
# 23                                   Mystery|Thriller  ...              R
# 24                              Action|Drama|Thriller  ...              R
# 25                              Biography|Crime|Drama  ...          PG-13
# 26                           Adventure|Drama|Thriller  ...              R
# 27                                      Drama|Romance  ...              R
# 28                                   Action|Adventure  ...          PG-13
# 29                              Biography|Crime|Drama  ...              R
# 30                            Action|Thriller|Western  ...              R
# 31                                              Drama  ...          PG-13
# 32                                      Drama|Romance  ...          PG-13
# 33                                      Drama|Romance  ...          PG-13
# 34                              Drama|Fantasy|Romance  ...          PG-13
# 35                                          Adventure  ...              R
# 36                                     Crime|Thriller  ...          PG-13
# 37               Action|Comedy|Crime|Romance|Thriller  ...          PG-13
# 38                              Action|Crime|Thriller  ...              R
# 39                                     Crime|Thriller  ...          PG-13
# 40                                   Action|Drama|War  ...              R
# 41              Adventure|Biography|Drama|History|War  ...          PG-13
# 42                                              Drama  ...              R
# 43  Adventure|Animation|Comedy|Drama|Family|Fantas...  ...             PG
# 44                               Drama|Fantasy|Horror  ...              R
# 45                                      Drama|Fantasy  ...          PG-13
# 46              Biography|Crime|Drama|History|Western  ...              R
# 47                                              Drama  ...              R
# 48                                      Drama|Romance  ...              R
# 49                                     Crime|Thriller  ...              R
# 50                Action|Crime|Drama|Romance|Thriller  ...              R
# 51                               Comedy|Music|Romance  ...              R
#
#     budget  title_year  actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0    85.00      2009.0                  2000.0        6.6          1.85
# 1    45.00      1994.0                   894.0        6.3          2.35
# 2    40.00      2009.0                   935.0        7.0          1.85
# 3    35.00      2006.0                 11000.0        6.8          2.35
# 4    35.00      2007.0                 10000.0        6.2          2.35
# 5    31.00      1985.0                   920.0        7.2          1.85
# 6    30.00      2012.0                  7000.0        6.3          2.35
# 7    30.00      1998.0                   882.0        7.0          1.85
# 8    29.00      2016.0                   183.0        7.1          2.35
# 9    25.00      2002.0                   577.0        7.6          1.85
# 25                15000  112.435221  Biography
# 26                    0  -10.221401  Adventure
# 27                    0  -12.122192      Drama
# 28                    0   21.876365     Action
# 29                16000    2.304950  Biography
# 30                    0  -13.363463     Action
# 31                 1000  -10.217492      Drama
# 32                10000   31.838728      Drama
# 33               115000   39.812796      Drama
# 34                23000  -22.509198      Drama
# 35                    0  -41.771652  Adventure
# 36                    0   15.531634      Crime
# 37                    0   66.336103     Action
# 38                    0  -91.973129     Action
# 39                    0   98.405771      Crime
# 40                82000   17.707116     Action
# 41                    0  -32.098491  Adventure
# 42                48000  -25.976605      Drama
# 43                  880  -33.711680  Adventure
# 44                11000   45.264608      Drama
# 45                39000  -18.696681      Drama
# 46                    0  -26.095018  Biography
# 47                    0    9.300771      Drama
# 48                    0   -9.468991      Drama
# 49                20000   -0.061430      Crime
# 50                15000   -0.718500     Action
# 51                  344         NaN     Comedy
#
#                                           genre_2
# 0                                   Drama|Romance
# 1                        Adventure|Crime|Thriller
# 2                                   Drama|Romance
# 3                                   Drama|Romance
# 4                                    Thriller|War
# 5                                   Drama|Romance
# 6                                   Drama|Romance
# 7                                           Drama
# 8                      Comedy|Drama|Music|Romance
# 9                                         Romance
# 10                                  Drama|History
# 11                                    Drama|Music
# 12                                          Drama
# 13                                        Romance
# 14                                        Romance
# 15                      Adventure|Sci-Fi|Thriller
# 16                         Drama|Thriller|Western
# 17                                          Drama
# 18                                        Western
# 19                                 Drama|Thriller
# 20                             Comedy|Crime|Drama
# 21                                          Drama
# 22                                 Drama|Thriller
# 23                                       Thriller
# 24                                 Drama|Thriller
# 25                                    Crime|Drama
# 26                                 Drama|Thriller
# 27                                        Romance
# 28                                      Adventure
# 29                                    Crime|Drama
# 30                               Thriller|Western
# 31                                          Drama
# 32                                        Romance
# 33                                        Romance
# 34                                Fantasy|Romance
# 35                                      Adventure
# 36                                       Thriller
# 37                  Comedy|Crime|Romance|Thriller
# 38                                 Crime|Thriller
# 39                                       Thriller
# 40                                      Drama|War
# 41                    Biography|Drama|History|War
# 42                                          Drama
# 43  Animation|Comedy|Drama|Family|Fantasy|Romance
# 44                                 Fantasy|Horror
# 45                                        Fantasy
# 46                    Crime|Drama|History|Western
# 47                                          Drama
# 48                                        Romance
# 49                                       Thriller
# 50                   Crime|Drama|Romance|Thriller
# 51                                  Music|Romance
#
# [52 rows x 31 columns]

# %%
# Write your code for grouping the combined dataframe here
group = Combined.groupby('actor_1_name')
group

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
actor_review_mean = group[['num_critic_for_reviews', 'num_user_for_reviews']].mean()
best_critic_reviews = actor_review_mean['num_critic_for_reviews'].idxmax()
best_user_reviews   = actor_review_mean['num_user_for_reviews'].idxmax()
print(actor_review_mean)
print('actor having highest critic reviews is : ',best_critic_reviews)
print('actor having highest mean user reviews  is : ',best_user_reviews)
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Brad Pitt                      231.944444            702.444444
# Leonardo DiCaprio              330.190476            914.476190
# Meryl Streep                   163.153846            257.307692
# actor having highest critic reviews is :  Leonardo DiCaprio
# actor having highest mean user reviews  is :  Leonardo DiCaprio

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
